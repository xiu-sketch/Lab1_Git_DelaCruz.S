# %%
import sys
print("System Check: PASSED")
print(f"Running on: {sys.version}")
# Out:
# System Check: PASSED
# Running on: 3.14.2 (tags/v3.14.2:df79316, Dec  5 2025, 17:18:21) [MSC v.1944 64 bit (AMD64)]

# %%
# !python --version
# Out:
# Python 3.14.2
